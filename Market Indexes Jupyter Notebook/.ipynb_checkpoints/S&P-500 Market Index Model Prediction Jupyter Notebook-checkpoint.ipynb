# %%
import pandas as pd
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
sp500_filepath="/Users/school/Documents/GitHub/Portfolio-Projects/Market Indexes Jupyter Notebook/sp500_index.csv"
sp500_data=pd.read_csv(sp500_filepath)
sp500_data.head()
# Out:
#          Date   S&P500
# 0  2013-06-03  1640.42
# 1  2013-06-04  1631.38
# 2  2013-06-05  1608.90
# 3  2013-06-06  1622.56
# 4  2013-06-07  1643.38

# %%
sp500_data['S&P500'].isna().sum()
# Out:
# 0

# %%
pd.to_datetime(sp500_data['Date'])
sp500_data.dtypes
# Out:
# Date       object
# S&P500    float64
# dtype: object

# %%
sns.lineplot(data=sp500_data,x=sp500_data['Date'],y=sp500_data['S&P500'],label="S&P500")
# Out:
# <Axes: xlabel='Date', ylabel='S&P500'>

# %%
NASDAQ_filepath = "/Users/school/Documents/GitHub/Portfolio-Projects/Market Indexes Jupyter Notebook/NASDAQ_100_Data_From_2010.csv"
nasdaq_data = pd.read_csv(NASDAQ_filepath)
nasdaq_data.head()
